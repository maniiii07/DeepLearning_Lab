# %% [markdown]
# ## LOAD LIBRARIES

# %%
from keras.models import Sequential
from keras.layers import Flatten, Dense, Conv2D, MaxPooling2D, Dropout
from keras.datasets import cifar10
from keras.utils import to_categorical
from keras.optimizers import Adam
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# ## load the data

# %%
(X_train,y_train),(X_test,y_test) = cifar10.load_data()

# %% [markdown]
# ## Preprocessing

# %%
#print(y_train[0])
y_train = to_categorical(y_train)

y_test = to_categorical(y_test)
#print(y_train[0])

# %% [markdown]
# ## Build Architecture

# %%
model = Sequential()
model.add(Conv2D(8,(3,3),activation = 'relu'))
model.add(MaxPooling2D((2,2)))
model.add(Flatten(input_shape=(32,32,3)))
model.add(Dense(units = 128, activation =  'relu'))
model.add(Dense(units = 10, activation = 'softmax'))

# %% [markdown]
# ## Compile

# %%
model.compile(optimizer='adam', loss = 'categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## Train

# %%
result = model.fit(X_train,y_train,epochs=32,batch_size=64, validation_data= (X_test,y_test))
# Out:
# Epoch 1/32
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.1973 - loss: 4.9825 - val_accuracy: 0.2686 - val_loss: 2.0494
# Epoch 2/32
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.3084 - loss: 1.8917 - val_accuracy: 0.3574 - val_loss: 1.7647
# Epoch 3/32
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.3885 - loss: 1.6707 - val_accuracy: 0.4062 - val_loss: 1.6342
# Epoch 4/32
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.4486 - loss: 1.5226 - val_accuracy: 0.4290 - val_loss: 1.5528
# Epoch 5/32
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.4895 - loss: 1.4134 - val_accuracy: 0.4798 - val_loss: 1.4684
# Epoch 6/32
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.5152 - loss: 1.3446 - val_accuracy: 0.4836 - val_loss: 1.4653
# Epoch 7/32
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.5361 - loss: 1.2888 - val_accuracy: 0.5130 - val_loss: 1.4115
# Epoch 8/32
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.5547 - loss: 1.2436 - val_accuracy: 0.5038 - val_loss: 1.4105
# Epoch 9/32
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.5697 - loss: 1.2078 - val_accuracy: 0.5173 - val_loss: 1.4609
# Epoch 10/32
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.5787 - loss: 1.1868 - val_accuracy: 0.5243 - val_loss: 1.4025
# Epoch 11/32
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.5906 - loss: 1.1522 - val_accuracy: 0.5001 - val_loss: 1.4753
# Epoch 12/32
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.5950 - loss: 1.1398 - val_accuracy: 0.5276 - val_loss: 1.3710
# Epoch 13/32
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.6084 - loss: 1.1109 - val_accuracy: 0.5372 - val_loss: 1.3897
# Epoch 14/32
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.6094 - loss: 1.1020 - val_accuracy: 0.5314 - val_loss: 1.4080
# Epoch 15/32
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.6194 - loss: 1.0769 - val_accuracy: 0.5284 - val_loss: 1.4361
# Epoch 16/32
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.6232 - loss: 1.0664 - val_accuracy: 0.5213 - val_loss: 1.5022
# Epoch 17/32
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.6317 - loss: 1.0440 - val_accuracy: 0.5318 - val_loss: 1.4577
# Epoch 18/32
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.6396 - loss: 1.0202 - val_accuracy: 0.5299 - val_loss: 1.4802
# Epoch 19/32
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.6444 - loss: 1.0067 - val_accuracy: 0.5222 - val_loss: 1.5337
# Epoch 20/32
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.6497 - loss: 0.9953 - val_accuracy: 0.5387 - val_loss: 1.4766
# Epoch 21/32
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.6549 - loss: 0.9747 - val_accuracy: 0.5254 - val_loss: 1.5798
# Epoch 22/32
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.6596 - loss: 0.9689 - val_accuracy: 0.5376 - val_loss: 1.4444
# Epoch 23/32
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.6654 - loss: 0.9508 - val_accuracy: 0.5379 - val_loss: 1.4944
# Epoch 24/32
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.6707 - loss: 0.9371 - val_accuracy: 0.5399 - val_loss: 1.5313
# Epoch 25/32
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.6743 - loss: 0.9251 - val_accuracy: 0.5257 - val_loss: 1.6508
# Epoch 26/32
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6815 - loss: 0.9079 - val_accuracy: 0.5325 - val_loss: 1.6357
# Epoch 27/32
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.6821 - loss: 0.9036 - val_accuracy: 0.5249 - val_loss: 1.6322
# Epoch 28/32
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.6851 - loss: 0.8910 - val_accuracy: 0.5320 - val_loss: 1.5992
# Epoch 29/32
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.6904 - loss: 0.8784 - val_accuracy: 0.5416 - val_loss: 1.6077
# Epoch 30/32
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6938 - loss: 0.8682 - val_accuracy: 0.5261 - val_loss: 1.6895
# Epoch 31/32
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.6934 - loss: 0.8691 - val_accuracy: 0.5447 - val_loss: 1.6333
# Epoch 32/32
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.6966 - loss: 0.8620 - val_accuracy: 0.5367 - val_loss: 1.5820

# %% [markdown]
# ## Evaluate

# %%
loss , accuracy = model.evaluate(X_test,y_test)
print(f"test accuracy:{accuracy}, test loss: {loss} ")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5367 - loss: 1.5820
# test accuracy:0.5367000102996826, test loss: 1.5819833278656006

# %% [markdown]
# ## Visualization

# %%
plt.plot(result.history['accuracy'],label='Train accuracy', color='blue')
plt.plot(result.history['val_accuracy'], label='test accuracy',color ='red')
plt.legend()
plt.title("Epoch Vs Accuracy on train and test data")
plt.show()

# %%
plt.plot(result.history['loss'],label='Train loss', color='blue')
plt.plot(result.history['val_loss'], label='test loss',color='red')
plt.legend()
plt.title("Epoch Vs Loss on train and test data")
plt.show()
